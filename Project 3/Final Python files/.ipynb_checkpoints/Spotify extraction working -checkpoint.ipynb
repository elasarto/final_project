# %%
import sys
import spotipy
import spotipy.util as util
from spotipy import oauth2
import json
import os
import re

import pandas as pd
import numpy as np

from matplotlib import pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
scope = 'user-library-read'

username = '7yp23sdg5ptloppevj62zjn6a'

token = util.prompt_for_user_token(username, scope,client_id = "944cef2fde194a8e8d4d5e8db666e020",
                                   client_secret = "52f43621583e4844a4728a5577617f24",
                                   redirect_uri = 'https://example.com/callback/')#, SPOTIPY_REDIRECT_URI)

if token:
    sp = spotipy.Spotify(auth=token)
    results = sp.current_user_saved_tracks()
    for item in results['items']:
        track = item['track']
        print (track['name'] + ' - ' + track['artists'][0]['name'])
else:
    print ("Can't get token for", username)

# %% [markdown]
# # Obtaining information for a specific user

# %%
username = input("What's the username?")

sp = spotipy.Spotify(auth=token)
playlists = sp.user_playlists(username)
#print(json.dumps(playlists, indent =2))
# Out:
# What's the username?dangerousmousepad

# %%
print("The playlist name is " + playlists['items'][0]['name'])
print("the playlist id is " + (playlists['items'][0]['uri']).split("playlist:")[1])
print("The total number of songs is " + str(playlists['items'][0]['tracks']['total']))
# Out:
# The playlist name is simons b'day
# the playlist id is 7yJ7rti7w00X00MVkb7Mlf
# The total number of songs is 5

# %%
playlist_name = []
playlist_id = []
playlist_total_songs = []

for i in playlists['items']:
    playlist_name.append(i['name'])
    playlist_id.append(i['uri'].split("playlist:")[1])
    playlist_total_songs.append(str(i['tracks']['total']))
    
print(len(playlist_name))
print(playlist_name)
print(len(playlist_id))
print(playlist_id)
print(len(playlist_total_songs))
print(playlist_total_songs)
# Out:
# 7
# ["simons b'day", 'Indie Darlings', 'SXSW: HipHopUpNext', '', 'SXSW Best Indie', 'Big beat fluff n stuff', 'indie playlist']
# 7
# ['7yJ7rti7w00X00MVkb7Mlf', '3MA1B86TKQJ5kO4m24DZFr', '37i9dQZF1DX5PuwKY2VZBZ', '37i9dQZF1DWZ78O1iz38e7', '37i9dQZF1DX6CwQbybVjjk', '140xloJquE5ryA0kKyigqD', '76HK2sBZd4AJjqElrfgT7O']
# 7
# ['5', '58', '25', '0', '59', '85', '212']

# %% [markdown]
# # Obtaining the list of all songs in each playlist

# %%
playlist_info = {}

playlist_name = []
playlist_owner = []
owner_type = []
playlist_followers = []
artist_id = []
artist_name = []
album_name = []
song_name = []
song_id = []
song_popularity = []



for p_id in playlist_id:
    #print(p_id)
    try:
        results = sp.user_playlist(username, p_id)
    except Exception:
        print('Cannot find following playlist id: ' + p_id)
        continue
    
    #print(json.dumps(results,indent=4))

    for i in results['tracks']['items']:
        playlist_name.append(results['name'])
        playlist_owner.append(results['owner']['id'])
        owner_type.append(results['owner']['type'])
        playlist_followers.append(results['followers']['total'])
        artist_id.append(i['track']['artists'][0]['id'])
        artist_name.append(i['track']['artists'][0]['name'])
        album_name.append(i['track']['album']['name'])
        song_name.append(i['track']['name'])
        song_id.append(i['track']['id'])
        song_popularity.append(i['track']['popularity'])
        
    
# print(playlist_name)
# print(playlist_owner)
# print(owner_type)
# print(playlist_followers)
# print(artist_id)
# print(artist_name)
# print(album_name)
# print(song_name)
# print(song_id)
# print(song_popularity)
# print(len(song_popularity))
# Out:
# Cannot find following playlist id: 37i9dQZF1DWZ78O1iz38e7

# %%
playlists_info = {'Playlist Name' : playlist_name, 'Playlist Owner' : playlist_owner, 'Owner Type' : owner_type, 
                 'Playlist Followers' : playlist_followers, 'Artist ID' : artist_id, 'Artist Name' : artist_name,
                 'Album Name' : album_name, 'Song Name' : song_name, 'Song ID' : song_id, 'Song Popularity' : song_popularity}

# %%
#print(playlists_info)

# %%
playlists_info_df = pd.DataFrame(playlists_info, columns = ['Playlist Name', 'Playlist Owner', 'Owner Type', 
                 'Playlist Followers', 'Artist ID', 'Artist Name','Album Name', 'Song Name', 'Song ID', 'Song Popularity'])

# %%
playlists_info_df.head()
# Out:
#   Playlist Name     Playlist Owner Owner Type  Playlist Followers  \
# 0  simons b'day  dangerousmousepad       user                   0
# 1  simons b'day  dangerousmousepad       user                   0
# 2  simons b'day  dangerousmousepad       user                   0
# 3  simons b'day  dangerousmousepad       user                   0
# 4  simons b'day  dangerousmousepad       user                   0
#
#                 Artist ID        Artist Name  \
# 0  7EV6jW6dotBdvsHj6xPixi  The Divine Comedy
# 1  3iTsJGG39nMg9YiolUgLMQ          Morrissey
# 2  4Bi9nN2hURgaENoxuvJ6Jt               Moco
# 3  3WrFJ7ztbogyGnTHbHJFl2        The Beatles
# 4  5fScAXreYFnuqwOgBsJgSd     The Charlatans
#
#                            Album Name  \
# 0          Victory For The Comic Muse
# 1                           Bona Drag
# 2               Twice Bitten Once Shy
# 3                      1 (Remastered)
# 4  Tellin' Stories - Expanded Edition
#
#                                            Song Name                 Song ID  \
# 0                            A Lady Of A Certain Age  1R8uTKKZTWnHRkkpFWcJfd
# 1  The Last of the Famous International Playboys ...  6162MRbYpLu1ZJHe7zHh8H
# 2                              Twice Bitten Once Shy  4sFhx3eU00RrmrOsJxEnAs
# 3                         Hey Jude - Remastered 2015  3H7sv3Krffn15BufUuXzf3
# 4                     North country Boy (Remastered)  14KZSrPmnLV3zFRxddFGor
#
#    Song Popularity
# 0               42
# 1               48
# 2                1
# 3               69
# 4               19

# %%
playlists_info_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 332 entries, 0 to 331
# Data columns (total 10 columns):
# Playlist Name         332 non-null object
# Playlist Owner        332 non-null object
# Owner Type            332 non-null object
# Playlist Followers    332 non-null int64
# Artist ID             332 non-null object
# Artist Name           332 non-null object
# Album Name            332 non-null object
# Song Name             332 non-null object
# Song ID               332 non-null object
# Song Popularity       332 non-null int64
# dtypes: int64(2), object(8)
# memory usage: 26.0+ KB

# %% [markdown]
# # Obtaining the features for each song contained in the playlist

# %%
song_id_2 = []
danceability = []
energy = []
key = []
loudness = []
mode = []
speechiness = []
acousticness = []
instrumentalness = []
liveness = []
valence = []
tempo = []
duration_ms = []

for s_id in song_id:
    features = sp.audio_features(s_id)
    #print(features)
    print(json.dumps(features, indent = 4))
    for feature in features:
        song_id_2.append(s_id)
        danceability.append(feature['danceability'])
        energy.append(feature['energy'])
        key.append(feature['key'])
        loudness.append(feature['loudness'])
        mode.append(feature['mode'])
        speechiness.append(feature['speechiness'])
        acousticness.append(feature['acousticness'])
        instrumentalness.append(feature['instrumentalness'])
        liveness.append(feature['liveness'])
        valence.append(feature['valence'])
        tempo.append(feature['tempo'])
        duration_ms.append(feature['duration_ms'])
# Out:
# [
#     {
#         "danceability": 0.441,
#         "energy": 0.512,
#         "key": 3,
#         "loudness": -10.785,
#         "mode": 1,
#         "speechiness": 0.0387,
#         "acousticness": 0.802,
#         "instrumentalness": 0.00264,
#         "liveness": 0.111,
#         "valence": 0.383,
#         "tempo": 87.815,
#         "type": "audio_features",
#         "id": "1R8uTKKZTWnHRkkpFWcJfd",
#         "uri": "spotify:track:1R8uTKKZTWnHRkkpFWcJfd",
#         "track_href": "https://api.spotify.com/v1/tracks/1R8uTKKZTWnHRkkpFWcJfd",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/1R8uTKKZTWnHRkkpFWcJfd",
#         "duration_ms": 350173,
#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.62,
#         "energy": 0.902,
#         "key": 7,
#         "loudness": -4.967,
#         "mode": 1,
#         "speechiness": 0.027,
#         "acousticness": 0.0293,
#         "instrumentalness": 0,
#         "liveness": 0.112,
#         "valence": 0.775,
#         "tempo": 104.255,
#         "type": "audio_features",
#         "id": "6162MRbYpLu1ZJHe7zHh8H",
#         "uri": "spotify:track:6162MRbYpLu1ZJHe7zHh8H",
#         "track_href": "https://api.spotify.com/v1/tracks/6162MRbYpLu1ZJHe7zHh8H",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/6162MRbYpLu1ZJHe7zHh8H",
#         "duration_ms": 217787,
#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.216,
#         "energy": 0.829,
#         "key": 11,
#         "loudness": -3.583,
#         "mode": 0,
#         "speechiness": 0.0443,
#         "acousticness": 0.00174,
#         "instrumentalness": 0.527,
#         "liveness": 0.0772,
#         "valence": 0.665,
#         "tempo": 179.758,
#         "type": "audio_features",
#         "id": "4sFhx3eU00RrmrOsJxEnAs",
#         "uri": "spotify:track:4sFhx3eU00RrmrOsJxEnAs",
#         "track_href": "https://api.spotify.com/v1/tracks/4sFhx3eU00RrmrOsJxEnAs",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/4sFhx3eU00RrmrOsJxEnAs",
#         "duration_ms": 207760,
#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.386,
#         "energy": 0.607,
#         "key": 10,
#         "loudness": -7.7,
#         "mode": 1,
#         "speechiness": 0.0261,
#         "acousticness": 0.0112,
#         "instrumentalness": 1.38e-05,
#         "liveness": 0.088,
#         "valence": 0.532,
#         "tempo": 147.207,
#         "type": "audio_features",
#         "id": "3H7sv3Krffn15BufUuXzf3",
#         "uri": "spotify:track:3H7sv3Krffn15BufUuXzf3",
#         "track_href": "https://api.spotify.com/v1/tracks/3H7sv3Krffn15BufUuXzf3",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/3H7sv3Krffn15BufUuXzf3",
#         "duration_ms": 425653,
#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.398,
#         "energy": 0.876,
#         "key": 11,
#         "loudness": -7.201,
#         "mode": 0,
#         "speechiness": 0.0412,
#         "acousticness": 0.00123,
#         "instrumentalness": 0,
#         "liveness": 0.264,
#         "valence": 0.52,
#         "tempo": 85.52,
#         "type": "audio_features",
#         "id": "14KZSrPmnLV3zFRxddFGor",
#         "uri": "spotify:track:14KZSrPmnLV3zFRxddFGor",
#         "track_href": "https://api.spotify.com/v1/tracks/14KZSrPmnLV3zFRxddFGor",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/14KZSrPmnLV3zFRxddFGor",
#         "duration_ms": 244667,
#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0

#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.519,
#         "energy": 0.636,
#         "key": 3,
#         "loudness": -7.822,
#         "mode": 0,
#         "speechiness": 0.035,
#         "acousticness": 0.0764,
#         "instrumentalness": 0.000492,
#         "liveness": 0.142,
#         "valence": 0.24,
#         "tempo": 107.072,
#         "type": "audio_features",
#         "id": "7rlg4YMSJLUdqblhIgWfy9",
#         "uri": "spotify:track:7rlg4YMSJLUdqblhIgWfy9",
#         "track_href": "https://api.spotify.com/v1/tracks/7rlg4YMSJLUdqblhIgWfy9",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/7rlg4YMSJLUdqblhIgWfy9",
#         "duration_ms": 242827,
#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.668,
#         "energy": 0.515,
#         "key": 7,
#         "loudness": -6.033,
#         "mode": 0,
#         "speechiness": 0.25,
#         "acousticness": 0.046,
#         "instrumentalness": 0,
#         "liveness": 0.17,
#         "valence": 0.64,
#         "tempo": 86.505,
#         "type": "audio_features",
#         "id": "7AssxKowBMbJidVrfUwk1m",
#         "uri": "spotify:track:7AssxKowBMbJidVrfUwk1m",
#         "track_href": "https://api.spotify.com/v1/tracks/7AssxKowBMbJidVrfUwk1m",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/7AssxKowBMbJidVrfUwk1m",
#         "duration_ms": 211712,
#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.413,
#         "energy": 0.635,
#         "key": 6,
#         "loudness": -6.115,
#         "mode": 0,
#         "speechiness": 0.0749,
#         "acousticness": 0.568,
#         "instrumentalness": 3.63e-06,
#         "liveness": 0.358,
#         "valence": 0.148,
#         "tempo": 129.209,
#         "type": "audio_features",
#         "id": "6rmJUbUoVNkb4rTOBm7M1A",
#         "uri": "spotify:track:6rmJUbUoVNkb4rTOBm7M1A",
#         "track_href": "https://api.spotify.com/v1/tracks/6rmJUbUoVNkb4rTOBm7M1A",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/6rmJUbUoVNkb4rTOBm7M1A",
#         "duration_ms": 240440,
#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.643,
#         "energy": 0.83,
#         "key": 11,
#         "loudness": -5.996,
#         "mode": 1,
#         "speechiness": 0.039,
#         "acousticness": 0.00323,
#         "instrumentalness": 1.2e-06,
#         "liveness": 0.175,
#         "valence": 0.884,
#         "tempo": 107.02,
#         "type": "audio_features",
#         "id": "7jAlKIlV7VHrFFvrMSFNPS",
#         "uri": "spotify:track:7jAlKIlV7VHrFFvrMSFNPS",
#         "track_href": "https://api.spotify.com/v1/tracks/7jAlKIlV7VHrFFvrMSFNPS",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/7jAlKIlV7VHrFFvrMSFNPS",
#         "duration_ms": 183734,
#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.489,
#         "energy": 0.625,
#         "key": 4,
#         "loudness": -5.652,
#         "mode": 1,
#         "speechiness": 0.0368,
#         "acousticness": 0.0436,
#         "instrumentalness": 0,
#         "liveness": 0.14,
#         "valence": 0.463,
#         "tempo": 130.035,
#         "type": "audio_features",
#         "id": "6D99HChRGsm8FJafpxXPux",
#         "uri": "spotify:track:6D99HChRGsm8FJafpxXPux",
#         "track_href": "https://api.spotify.com/v1/tracks/6D99HChRGsm8FJafpxXPux",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/6D99HChRGsm8FJafpxXPux",
#         "duration_ms": 198600,
#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.121,
#         "energy": 0.828,
#         "key": 4,
#         "loudness": -4.248,
#         "mode": 1,
#         "speechiness": 0.0576,
#         "acousticness": 0.0214,
#         "instrumentalness": 0,
#         "liveness": 0.229,
#         "valence": 0.527,
#         "tempo": 205.061,
#         "type": "audio_features",
#         "id": "1ZZr5C2vRZCUCrFtHdtWlT",
#         "uri": "spotify:track:1ZZr5C2vRZCUCrFtHdtWlT",
#         "track_href": "https://api.spotify.com/v1/tracks/1ZZr5C2vRZCUCrFtHdtWlT",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/

#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/4O3gIvlJvI6l4S0282V6T1",
#         "duration_ms": 228672,
#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.699,
#         "energy": 0.752,
#         "key": 4,
#         "loudness": -5.612,
#         "mode": 0,
#         "speechiness": 0.0299,
#         "acousticness": 0.326,
#         "instrumentalness": 2.62e-05,
#         "liveness": 0.0669,
#         "valence": 0.729,
#         "tempo": 99.964,
#         "type": "audio_features",
#         "id": "2kUn5FYkGy5HR5W62kHfkp",
#         "uri": "spotify:track:2kUn5FYkGy5HR5W62kHfkp",
#         "track_href": "https://api.spotify.com/v1/tracks/2kUn5FYkGy5HR5W62kHfkp",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/2kUn5FYkGy5HR5W62kHfkp",
#         "duration_ms": 222093,
#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.595,
#         "energy": 0.699,
#         "key": 1,
#         "loudness": -5.113,
#         "mode": 1,
#         "speechiness": 0.025,
#         "acousticness": 0.00367,
#         "instrumentalness": 7.46e-05,
#         "liveness": 0.368,
#         "valence": 0.481,
#         "tempo": 92.496,
#         "type": "audio_features",
#         "id": "23ImZO2UEsDFttkbS5R0rG",
#         "uri": "spotify:track:23ImZO2UEsDFttkbS5R0rG",
#         "track_href": "https://api.spotify.com/v1/tracks/23ImZO2UEsDFttkbS5R0rG",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/23ImZO2UEsDFttkbS5R0rG",
#         "duration_ms": 256998,
#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.621,
#         "energy": 0.527,
#         "key": 11,
#         "loudness": -6.597,
#         "mode": 1,
#         "speechiness": 0.032,
#         "acousticness": 0.135,
#         "instrumentalness": 0.00402,
#         "liveness": 0.064,
#         "valence": 0.846,
#         "tempo": 171.925,
#         "type": "audio_features",
#         "id": "6Ruj78T9Lfu6fS4wwwh5bE",
#         "uri": "spotify:track:6Ruj78T9Lfu6fS4wwwh5bE",
#         "track_href": "https://api.spotify.com/v1/tracks/6Ruj78T9Lfu6fS4wwwh5bE",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/6Ruj78T9Lfu6fS4wwwh5bE",
#         "duration_ms": 215520,
#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.577,
#         "energy": 0.438,
#         "key": 6,
#         "loudness": -10.079,
#         "mode": 1,
#         "speechiness": 0.0345,
#         "acousticness": 0.864,
#         "instrumentalness": 0.0168,
#         "liveness": 0.103,
#         "valence": 0.146,
#         "tempo": 98.944,
#         "type": "audio_features",
#         "id": "3XdmXkx1UvwOSlE0bV0Kqj",
#         "uri": "spotify:track:3XdmXkx1UvwOSlE0bV0Kqj",
#         "track_href": "https://api.spotify.com/v1/tracks/3XdmXkx1UvwOSlE0bV0Kqj",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/3XdmXkx1UvwOSlE0bV0Kqj",
#         "duration_ms": 200830,
#         "time_signature": 3
#     }
# ]
# [
#     {
#         "danceability": 0.557,
#         "energy": 0.821,
#         "key": 9,
#         "loudness": -5.309,
#         "mode": 1,
#         "speechiness": 0.0537,
#         "acousticness": 0.45,
#         "instrumentalness": 0,
#         "liveness": 0.36,
#         "valence": 0.524,
#         "tempo": 131.912,
#         "type": "audio_features",
#         "id": "4FFjpAcXSuvRCURxuipDRE",
#         "uri": "spotify:track:4FFjpAcXSuvRCURxuipDRE",
#         "track_href": "https://api.spotify.com/v1/tracks/4FFjpAcXSuvRCURxuipDRE",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/

#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.619,
#         "energy": 0.9,
#         "key": 9,
#         "loudness": -6.041,
#         "mode": 1,
#         "speechiness": 0.0472,
#         "acousticness": 0.00264,
#         "instrumentalness": 0.0565,
#         "liveness": 0.367,
#         "valence": 0.774,
#         "tempo": 100.029,
#         "type": "audio_features",
#         "id": "3oD0K903AP8l8CqwAv1bOg",
#         "uri": "spotify:track:3oD0K903AP8l8CqwAv1bOg",
#         "track_href": "https://api.spotify.com/v1/tracks/3oD0K903AP8l8CqwAv1bOg",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/3oD0K903AP8l8CqwAv1bOg",
#         "duration_ms": 191640,
#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.633,
#         "energy": 0.715,
#         "key": 6,
#         "loudness": -7.244,
#         "mode": 1,
#         "speechiness": 0.0304,
#         "acousticness": 0.0647,
#         "instrumentalness": 0,
#         "liveness": 0.103,
#         "valence": 0.526,
#         "tempo": 126.935,
#         "type": "audio_features",
#         "id": "7JPIRFlQL2acGnyqujDrDQ",
#         "uri": "spotify:track:7JPIRFlQL2acGnyqujDrDQ",
#         "track_href": "https://api.spotify.com/v1/tracks/7JPIRFlQL2acGnyqujDrDQ",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/7JPIRFlQL2acGnyqujDrDQ",
#         "duration_ms": 228458,
#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.57,
#         "energy": 0.833,
#         "key": 4,
#         "loudness": -4.368,
#         "mode": 1,
#         "speechiness": 0.0681,
#         "acousticness": 0.000889,
#         "instrumentalness": 0.267,
#         "liveness": 0.141,
#         "valence": 0.714,
#         "tempo": 129.114,
#         "type": "audio_features",
#         "id": "4VWfey4ts0aMjxjyDwJGO7",
#         "uri": "spotify:track:4VWfey4ts0aMjxjyDwJGO7",
#         "track_href": "https://api.spotify.com/v1/tracks/4VWfey4ts0aMjxjyDwJGO7",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/4VWfey4ts0aMjxjyDwJGO7",
#         "duration_ms": 148355,
#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.482,
#         "energy": 0.868,
#         "key": 0,
#         "loudness": -5.258,
#         "mode": 1,
#         "speechiness": 0.0488,
#         "acousticness": 0.0144,
#         "instrumentalness": 0,
#         "liveness": 0.126,
#         "valence": 0.347,
#         "tempo": 120.067,
#         "type": "audio_features",
#         "id": "5rqkJzlKCZCEAEhoJuasWm",
#         "uri": "spotify:track:5rqkJzlKCZCEAEhoJuasWm",
#         "track_href": "https://api.spotify.com/v1/tracks/5rqkJzlKCZCEAEhoJuasWm",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/5rqkJzlKCZCEAEhoJuasWm",
#         "duration_ms": 218089,
#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.257,
#         "energy": 0.269,
#         "key": 10,
#         "loudness": -11.344,
#         "mode": 1,
#         "speechiness": 0.0331,
#         "acousticness": 0.778,
#         "instrumentalness": 0.231,
#         "liveness": 0.112,
#         "valence": 0.0717,
#         "tempo": 93.45,
#         "type": "audio_features",
#         "id": "5dzKyPT9eeUsIXKRn6T1Uz",
#         "uri": "spotify:track:5dzKyPT9eeUsIXKRn6T1Uz",
#         "track_href": "https://api.spotify.com/v1/tracks/5dzKyPT9eeUsIXKRn6T1Uz",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/5dzKyPT9eeUsIXKRn6T1Uz",
#         "duration_ms": 229279,
#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.58,
#         "energy": 0.74,
#         "key": 3,
#         "loudness": -7.404,
#         "mode": 1,
#         "speechiness": 0.0491,
#         "acousticness": 0.242,
#         "instrumentalness": 0.000291,
#         "liveness": 0.102,
#         "valence": 0.633,
#         "tempo": 137.036,
#         "type": "audio_features",
#         "id": "1OCLpatReeEFSuvINgzVp0",
#         "uri": "spotify:track:1OCLpatReeEFSuvINgzVp0",
#         "track_href": "https://api.spotify.com/v1/tracks/1OCLpatReeEFSuvINgzVp0",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/1OCLpatReeEFSuvINgzVp0",
#         "duration_ms": 234481,
#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.31,
#         "energy": 0.917,
#         "key": 11,
#         "loudness": -7.501,
#         "mode": 1,
#         "speechiness": 0.0924,
#         "acousticness": 0.00193,
#         "instrumentalness": 0.126,
#         "liveness": 0.367,
#         "valence": 0.544,
#         "tempo": 152.1,
#         "type": "audio_features",
#         "id": "7iXC3BTtnfg520LQ914WOR",
#         "uri": "spotify:track:7iXC3BTtnfg520LQ914WOR",
#         "track_href": "https://api.spotify.com/v1/tracks/7iXC3BTtnfg520LQ914WOR",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/7iXC3BTtnfg520LQ914WOR",
#         "duration_ms": 192267,
#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.235,
#         "energy": 0.685,
#         "key": 4,
#         "loudness": -8.798,
#         "mode": 1,
#         "speechiness": 0.0392,
#         "acousticness": 0.399,
#         "instrumentalness": 0.69,
#         "liveness": 0.748,
#         "valence": 0.369,
#         "tempo": 142.31,
#         "type": "audio_features",
#         "id": "0Lw53p9qMn4nu2JkPlaxLC",
#         "uri": "spotify:track:0Lw53p9qMn4nu2JkPlaxLC",
#         "track_href": "https://api.spotify.com/v1/tracks/0Lw53p9qMn4nu2JkPlaxLC",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/0Lw53p9qMn4nu2JkPlaxLC",
#         "duration_ms": 217206,
#         "time_signature": 3
#     }
# ]
# [
#     {
#         "danceability": 0.567,
#         "energy": 0.757,
#         "key": 7,
#         "loudness": -5.998,
#         "mode": 1,
#         "speechiness": 0.0375,
#         "acousticness": 0.297,
#         "instrumentalness": 0,
#         "liveness": 0.1,
#         "valence": 0.759,
#         "tempo": 97.183,
#         "type": "audio_features",
#         "id": "0DFTtxA0UpZkKn8C4kpKVi",
#         "uri": "spotify:track:0DFTtxA0UpZkKn8C4kpKVi",
#         "track_href": "https://api.spotify.com/v1/tracks/0DFTtxA0UpZkKn8C4kpKVi",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/0DFTtxA0UpZkKn8C4kpKVi",
#         "duration_ms": 220174,
#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.68,
#         "energy": 0.608,
#         "key": 10,
#         "loudness": -9.403,
#         "mode": 1,
#         "speechiness": 0.0394,
#         "acousticness": 0.152,
#         "instrumentalness": 0.0187,
#         "liveness": 0.183,
#         "valence": 0.712,
#         "tempo": 107.374,
#         "type": "audio_features",
#         "id": "6vIB6OmF6n8Ne4NtlVDoTI",
#         "uri": "spotify:track:6vIB6OmF6n8Ne4NtlVDoTI",
#         "track_href": "https://api.spotify.com/v1/tracks/6vIB6OmF6n8Ne4NtlVDoTI",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/6vIB6OmF6n8Ne4NtlVDoTI",
#         "duration_ms": 239249,
#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.489,
#         "energy": 0.757,
#         "key": 8,
#         "loudness": -6.781,
#         "mode": 0,
#         "speechiness": 0.0341,
#         "acousticness": 0.188,
#         "instrumentalness": 0.129,
#         "liveness": 0.19,
#         "valence": 0.123,
#         "tempo": 132.002,
#         "type": "audio_features",
#         "id": "58n7oiIJLYC20K4MulbTer",
#         "uri": "spotify:track:58n7oiIJLYC20K4MulbTer",
#         "track_href": "https://api.spotify.com/v1/tracks/58n7oiIJLYC20K4MulbTer",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis

#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.841,
#         "energy": 0.536,
#         "key": 6,
#         "loudness": -8.214,
#         "mode": 1,
#         "speechiness": 0.0361,
#         "acousticness": 0.0333,
#         "instrumentalness": 0.00408,
#         "liveness": 0.105,
#         "valence": 0.531,
#         "tempo": 99.045,
#         "type": "audio_features",
#         "id": "380xj2st2v2ep1tyL22wkZ",
#         "uri": "spotify:track:380xj2st2v2ep1tyL22wkZ",
#         "track_href": "https://api.spotify.com/v1/tracks/380xj2st2v2ep1tyL22wkZ",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/380xj2st2v2ep1tyL22wkZ",
#         "duration_ms": 207747,
#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.412,
#         "energy": 0.938,
#         "key": 0,
#         "loudness": -2.77,
#         "mode": 1,
#         "speechiness": 0.175,
#         "acousticness": 0.106,
#         "instrumentalness": 1.58e-05,
#         "liveness": 0.857,
#         "valence": 0.821,
#         "tempo": 92.628,
#         "type": "audio_features",
#         "id": "0QAEc5JBdaZMdxqU3xL64H",
#         "uri": "spotify:track:0QAEc5JBdaZMdxqU3xL64H",
#         "track_href": "https://api.spotify.com/v1/tracks/0QAEc5JBdaZMdxqU3xL64H",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/0QAEc5JBdaZMdxqU3xL64H",
#         "duration_ms": 194693,
#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.149,
#         "energy": 0.615,
#         "key": 7,
#         "loudness": -4.897,
#         "mode": 1,
#         "speechiness": 0.036,
#         "acousticness": 0.00245,
#         "instrumentalness": 0,
#         "liveness": 0.0798,
#         "valence": 0.156,
#         "tempo": 155.591,
#         "type": "audio_features",
#         "id": "6llIaMotP9Yr8ozgPl8hwl",
#         "uri": "spotify:track:6llIaMotP9Yr8ozgPl8hwl",
#         "track_href": "https://api.spotify.com/v1/tracks/6llIaMotP9Yr8ozgPl8hwl",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/6llIaMotP9Yr8ozgPl8hwl",
#         "duration_ms": 143571,
#         "time_signature": 3
#     }
# ]
# [
#     {
#         "danceability": 0.347,
#         "energy": 0.617,
#         "key": 7,
#         "loudness": -10.126,
#         "mode": 1,
#         "speechiness": 0.0762,
#         "acousticness": 0.122,
#         "instrumentalness": 0.000138,
#         "liveness": 0.103,
#         "valence": 0.307,
#         "tempo": 100.023,
#         "type": "audio_features",
#         "id": "34LL3e0iVDwPTHxmAFUb3k",
#         "uri": "spotify:track:34LL3e0iVDwPTHxmAFUb3k",
#         "track_href": "https://api.spotify.com/v1/tracks/34LL3e0iVDwPTHxmAFUb3k",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/34LL3e0iVDwPTHxmAFUb3k",
#         "duration_ms": 294999,
#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.775,
#         "energy": 0.786,
#         "key": 5,
#         "loudness": -5.804,
#         "mode": 0,
#         "speechiness": 0.0533,
#         "acousticness": 0.025,
#         "instrumentalness": 0.0549,
#         "liveness": 0.189,
#         "valence": 0.906,
#         "tempo": 93.039,
#         "type": "audio_features",
#         "id": "0OWp92NxOX1vbhlZRpMye3",
#         "uri": "spotify:track:0OWp92NxOX1vbhlZRpMye3",
#         "track_href": "https://api.spotify.com/v1/tracks/0OWp92NxOX1vbhlZRpMye3",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/0OWp92NxOX1vbhlZRpMye3",
#         "duration_ms": 223627,
#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.504,
#         "energy": 0.682,
#         "key": 9,
#         "loudness": -5.702,
#         "mode": 1,
#         "speechiness": 0.0332,
#         "acousticness": 0.0002,
#         "instrumentalness": 0.00205,
#         "liveness": 0.147,
#         "valence": 0.207,
#         "tempo": 123.848,
#         "type": "audio_features",
#         "id": "3twm1m2HtONUDBkUE4iPju",
#         "uri": "spotify:track:3twm1m2HtONUDBkUE4iPju",
#         "track_href": "https://api.spotify.com/v1/tracks/3twm1m2HtONUDBkUE4iPju",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/3twm1m2HtONUDBkUE4iPju",
#         "duration_ms": 308347,
#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.714,
#         "energy": 0.713,
#         "key": 2,
#         "loudness": -5.52,
#         "mode": 0,
#         "speechiness": 0.027,
#         "acousticness": 0.0114,
#         "instrumentalness": 0.0183,
#         "liveness": 0.0608,
#         "valence": 0.9,
#         "tempo": 93.006,
#         "type": "audio_features",
#         "id": "4AKN68fSI8weZ1dbN35QLi",
#         "uri": "spotify:track:4AKN68fSI8weZ1dbN35QLi",
#         "track_href": "https://api.spotify.com/v1/tracks/4AKN68fSI8weZ1dbN35QLi",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/4AKN68fSI8weZ1dbN35QLi",
#         "duration_ms": 208200,
#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.956,
#         "energy": 0.373,
#         "key": 6,
#         "loudness": -7.963,
#         "mode": 1,
#         "speechiness": 0.0773,
#         "acousticness": 0.569,
#         "instrumentalness": 0.394,
#         "liveness": 0.314,
#         "valence": 0.568,
#         "tempo": 119.994,
#         "type": "audio_features",
#         "id": "3DPFmwFtV5ElQaTniLOdgk",
#         "uri": "spotify:track:3DPFmwFtV5ElQaTniLOdgk",
#         "track_href": "https://api.spotify.com/v1/tracks/3DPFmwFtV5ElQaTniLOdgk",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/3DPFmwFtV5ElQaTniLOdgk",
#         "duration_ms": 268333,
#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.253,
#         "energy": 0.859,
#         "key": 4,
#         "loudness": -4.541,
#         "mode": 1,
#         "speechiness": 0.127,
#         "acousticness": 0.000658,
#         "instrumentalness": 0.873,
#         "liveness": 0.121,
#         "valence": 0.702,
#         "tempo": 150.17,
#         "type": "audio_features",
#         "id": "7F34TU4gcijPHMVSfacQoa",
#         "uri": "spotify:track:7F34TU4gcijPHMVSfacQoa",
#         "track_href": "https://api.spotify.com/v1/tracks/7F34TU4gcijPHMVSfacQoa",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/7F34TU4gcijPHMVSfacQoa",
#         "duration_ms": 195640,
#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.461,
#         "energy": 0.621,
#         "key": 1,
#         "loudness": -8.551,
#         "mode": 1,
#         "speechiness": 0.144,
#         "acousticness": 0.269,
#         "instrumentalness": 0.0718,
#         "liveness": 0.399,
#         "valence": 0.543,
#         "tempo": 175.876,
#         "type": "audio_features",
#         "id": "5URMGn47PS7P0eQpTtxm8I",
#         "uri": "spotify:track:5URMGn47PS7P0eQpTtxm8I",
#         "track_href": "https://api.spotify.com/v1/tracks/5URMGn47PS7P0eQpTtxm8I",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/5URMGn47PS7P0eQpTtxm8I",
#         "duration_ms": 199904,
#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.237,
#         "energy": 0.412,
#         "key": 4,
#         "loudness": -11.384,
#         "mode": 1,
#         "speechiness": 0.0299,
#         "acousticness": 0.0417,
#         "instrumentalness": 0.451,
#         "liveness": 0.107,
#         "valence": 0.364,
#         "tempo": 186.955,
#         "type": "audio_features",
#         "id": "73ROvjXlrsrDcNmCurwWOF",
#         "uri": "spotify:track:73ROvjXlrsrDcNmCurwWOF",
#         "track_href": "https://api.spotify.com/v1/tracks/73ROvjXlrsrDcNmCurwWOF",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis

#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/2vUhsPizP1kq7dqLSCrDmt",
#         "duration_ms": 192853,
#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.727,
#         "energy": 0.602,
#         "key": 1,
#         "loudness": -8.42,
#         "mode": 0,
#         "speechiness": 0.133,
#         "acousticness": 0.117,
#         "instrumentalness": 0,
#         "liveness": 0.0833,
#         "valence": 0.418,
#         "tempo": 129.952,
#         "type": "audio_features",
#         "id": "3jEtESxn2ngF25DMD6vbBg",
#         "uri": "spotify:track:3jEtESxn2ngF25DMD6vbBg",
#         "track_href": "https://api.spotify.com/v1/tracks/3jEtESxn2ngF25DMD6vbBg",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/3jEtESxn2ngF25DMD6vbBg",
#         "duration_ms": 177406,
#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.876,
#         "energy": 0.716,
#         "key": 5,
#         "loudness": -5.948,
#         "mode": 0,
#         "speechiness": 0.096,
#         "acousticness": 0.0473,
#         "instrumentalness": 1.38e-05,
#         "liveness": 0.113,
#         "valence": 0.402,
#         "tempo": 154.986,
#         "type": "audio_features",
#         "id": "5HvvNQEd62bveJqT1raHbw",
#         "uri": "spotify:track:5HvvNQEd62bveJqT1raHbw",
#         "track_href": "https://api.spotify.com/v1/tracks/5HvvNQEd62bveJqT1raHbw",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/5HvvNQEd62bveJqT1raHbw",
#         "duration_ms": 193593,
#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.8,
#         "energy": 0.586,
#         "key": 0,
#         "loudness": -7.344,
#         "mode": 1,
#         "speechiness": 0.176,
#         "acousticness": 0.037,
#         "instrumentalness": 0,
#         "liveness": 0.074,
#         "valence": 0.749,
#         "tempo": 104.002,
#         "type": "audio_features",
#         "id": "0lpRp9KzzMbC0w1uiL7H7f",
#         "uri": "spotify:track:0lpRp9KzzMbC0w1uiL7H7f",
#         "track_href": "https://api.spotify.com/v1/tracks/0lpRp9KzzMbC0w1uiL7H7f",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/0lpRp9KzzMbC0w1uiL7H7f",
#         "duration_ms": 221623,
#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.907,
# ...
#         "liveness": 0.547,
#         "valence": 0.457,
#         "tempo": 125.537,
#         "type": "audio_features",
#         "id": "3n2ujlr3mCscnFFpepXAIy",
#         "uri": "spotify:track:3n2ujlr3mCscnFFpepXAIy",
#         "track_href": "https://api.spotify.com/v1/tracks/3n2ujlr3mCscnFFpepXAIy",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/3n2ujlr3mCscnFFpepXAIy",
#         "duration_ms": 220533,
#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.247,
#         "energy": 0.902,
#         "key": 7,
#         "loudness": -2.478,
#         "mode": 1,
#         "speechiness": 0.0394,
#         "acousticness": 0.0428,
#         "instrumentalness": 0.0152,
#         "liveness": 0.309,
#         "valence": 0.313,
#         "tempo": 91.432,
#         "type": "audio_features",
#         "id": "1p7g8Z422tp6OALADuAVjC",
#         "uri": "spotify:track:1p7g8Z422tp6OALADuAVjC",
#         "track_href": "https://api.spotify.com/v1/tracks/1p7g8Z422tp6OALADuAVjC",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/1p7g8Z422tp6OALADuAVjC",
#         "duration_ms": 382267,
#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.236,
#         "energy": 0.944,
#         "key": 5,
#         "loudness": -2.693,
#         "mode": 0,
#         "speechiness": 0.0883,
#         "acousticness": 0.000117,
#         "instrumentalness": 0.000442,
#         "liveness": 0.325,
#         "valence": 0.256,
#         "tempo": 93.991,
#         "type": "audio_features",
#         "id": "6mKbN5qaeM2tcG3LRdeNLQ",
#         "uri": "spotify:track:6mKbN5qaeM2tcG3LRdeNLQ",
#         "track_href": "https://api.spotify.com/v1/tracks/6mKbN5qaeM2tcG3LRdeNLQ",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/6mKbN5qaeM2tcG3LRdeNLQ",
#         "duration_ms": 392307,
#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.586,
#         "energy": 0.433,
#         "key": 4,
#         "loudness": -10.851,
#         "mode": 1,
#         "speechiness": 0.0273,
#         "acousticness": 0.788,
#         "instrumentalness": 0,
#         "liveness": 0.0795,
#         "valence": 0.289,
#         "tempo": 87.272,
#         "type": "audio_features",
#         "id": "1u22VgixAwwvFt0WFwkPwf",
#         "uri": "spotify:track:1u22VgixAwwvFt0WFwkPwf",
#         "track_href": "https://api.spotify.com/v1/tracks/1u22VgixAwwvFt0WFwkPwf",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/1u22VgixAwwvFt0WFwkPwf",
#         "duration_ms": 195000,
#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.334,
#         "energy": 0.985,
#         "key": 2,
#         "loudness": -1.634,
#         "mode": 0,
#         "speechiness": 0.0913,
#         "acousticness": 0.00822,
#         "instrumentalness": 0.000199,
#         "liveness": 0.483,
#         "valence": 0.15,
#         "tempo": 136.98,
#         "type": "audio_features",
#         "id": "05KqIX6uLMfirw5KkjRNTO",
#         "uri": "spotify:track:05KqIX6uLMfirw5KkjRNTO",
#         "track_href": "https://api.spotify.com/v1/tracks/05KqIX6uLMfirw5KkjRNTO",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/05KqIX6uLMfirw5KkjRNTO",
#         "duration_ms": 303533,
#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.442,
#         "energy": 0.792,
#         "key": 7,
#         "loudness": -5.225,
#         "mode": 1,
#         "speechiness": 0.0297,
#         "acousticness": 0.00246,
#         "instrumentalness": 0,
#         "liveness": 0.179,
#         "valence": 0.537,
#         "tempo": 159.954,
#         "type": "audio_features",
#         "id": "5idxI74LP1QrwcMEzw4hkP",
#         "uri": "spotify:track:5idxI74LP1QrwcMEzw4hkP",
#         "track_href": "https://api.spotify.com/v1/tracks/5idxI74LP1QrwcMEzw4hkP",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/5idxI74LP1QrwcMEzw4hkP",
#         "duration_ms": 291600,
#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.346,
#         "energy": 0.916,
#         "key": 0,
#         "loudness": -3.588,
#         "mode": 1,
#         "speechiness": 0.0703,
#         "acousticness": 0.0331,
#         "instrumentalness": 3.82e-06,
#         "liveness": 0.117,
#         "valence": 0.249,
#         "tempo": 164.005,
#         "type": "audio_features",
#         "id": "3ixTiPABjqkBKPocxq6oIe",
#         "uri": "spotify:track:3ixTiPABjqkBKPocxq6oIe",
#         "track_href": "https://api.spotify.com/v1/tracks/3ixTiPABjqkBKPocxq6oIe",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/3ixTiPABjqkBKPocxq6oIe",
#         "duration_ms": 287827,
#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.369,
#         "energy": 0.62,
#         "key": 7,
#         "loudness": -6.39,
#         "mode": 1,
#         "speechiness": 0.0302,
#         "acousticness": 0.0982,
#         "instrumentalness": 5.85e-05,
#         "liveness": 0.0908,
#         "valence": 0.151,
#         "tempo": 149.611,
#         "type": "audio_features",
#         "id": "6Bwp4jLmnlTuow1miIpi1o",
#         "uri": "spotify:track:6Bwp4jLmnlTuow1miIpi1o",
#         "track_href": "https://api.spotify.com/v1/tracks/6Bwp4jLmnlTuow1miIpi1o",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/6Bwp4jLmnlTuow1miIpi1o",
#         "duration_ms": 322640,
#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.431,
#         "energy": 0.451,
#         "key": 0,
#         "loudness": -8.72,
#         "mode": 1,
#         "speechiness": 0.0325,
#         "acousticness": 0.284,
#         "instrumentalness": 0,
#         "liveness": 0.0738,
#         "valence": 0.205,
#         "tempo": 115.855,
#         "type": "audio_features",
#         "id": "6aM4E6WfuoDnPAgaKaZ5hM",
#         "uri": "spotify:track:6aM4E6WfuoDnPAgaKaZ5hM",
#         "track_href": "https://api.spotify.com/v1/tracks/6aM4E6WfuoDnPAgaKaZ5hM",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/6aM4E6WfuoDnPAgaKaZ5hM",
#         "duration_ms": 261800,
#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.138,
#         "energy": 0.985,
#         "key": 4,
#         "loudness": -3.309,
#         "mode": 1,
#         "speechiness": 0.152,
#         "acousticness": 2.27e-05,
#         "instrumentalness": 0.611,
#         "liveness": 0.382,
#         "valence": 0.038,
#         "tempo": 97.152,
#         "type": "audio_features",
#         "id": "4N8VDWQoAeihaRaZkR6AMN",
#         "uri": "spotify:track:4N8VDWQoAeihaRaZkR6AMN",
#         "track_href": "https://api.spotify.com/v1/tracks/4N8VDWQoAeihaRaZkR6AMN",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/4N8VDWQoAeihaRaZkR6AMN",
#         "duration_ms": 385293,
#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.207,
#         "energy": 0.958,
#         "key": 7,
#         "loudness": -1.798,
#         "mode": 1,
#         "speechiness": 0.0749,
#         "acousticness": 0.00835,
#         "instrumentalness": 0.000408,
#         "liveness": 0.408,
#         "valence": 0.214,
#         "tempo": 113.017,
#         "type": "audio_features",
#         "id": "3264xSjIMFRYyep6njzapi",
#         "uri": "spotify:track:3264xSjIMFRYyep6njzapi",
#         "track_href": "https://api.spotify.com/v1/tracks/3264xSjIMFRYyep6njzapi",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/3264xSjIMFRYyep6njzapi",
#         "duration_ms": 264960,
#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.737,
#         "energy": 0.831,
#         "key": 6,
#         "loudness": -5.025,
#         "mode": 0,
#         "speechiness": 0.037,
#         "acousticness": 0.272,
#         "instrumentalness": 0,
#         "liveness": 0.142,
#         "valence": 0.938,
#         "tempo": 119.898,
#         "type": "audio_features",
#         "id": "7ybdAawrcW67xFZGiQ998U",
#         "uri": "spotify:track:7ybdAawrcW67xFZGiQ998U",
#         "track_href": "https://api.spotify.com/v1/tracks/7ybdAawrcW67xFZGiQ998U",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/7ybdAawrcW67xFZGiQ998U",
#         "duration_ms": 251480,
#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.577,
#         "energy": 0.828,
#         "key": 7,
#         "loudness": -9.805,
#         "mode": 1,
#         "speechiness": 0.0556,
#         "acousticness": 0.358,
#         "instrumentalness": 0.013,
#         "liveness": 0.0683,
#         "valence": 0.706,
#         "tempo": 142.365,
#         "type": "audio_features",
#         "id": "5GPPI3rnZDptLYRN4vTUoZ",
#         "uri": "spotify:track:5GPPI3rnZDptLYRN4vTUoZ",
#         "track_href": "https://api.spotify.com/v1/tracks/5GPPI3rnZDptLYRN4vTUoZ",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/5GPPI3rnZDptLYRN4vTUoZ",
#         "duration_ms": 314067,
#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.843,
#         "energy": 0.57,
#         "key": 6,
#         "loudness": -9.873,
#         "mode": 0,
#         "speechiness": 0.0375,
#         "acousticness": 0.153,
#         "instrumentalness": 0.00445,
#         "liveness": 0.0978,
#         "valence": 0.962,
#         "tempo": 116.016,
#         "type": "audio_features",
#         "id": "5CmQgmKwmSf3ojZTuvHekY",
#         "uri": "spotify:track:5CmQgmKwmSf3ojZTuvHekY",
#         "track_href": "https://api.spotify.com/v1/tracks/5CmQgmKwmSf3ojZTuvHekY",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/5CmQgmKwmSf3ojZTuvHekY",
#         "duration_ms": 198307,
#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.495,
#         "energy": 0.712,
#         "key": 9,
#         "loudness": -6.565,
#         "mode": 0,
#         "speechiness": 0.0426,
#         "acousticness": 0.259,
#         "instrumentalness": 6.79e-06,
#         "liveness": 0.241,
#         "valence": 0.539,
#         "tempo": 154.286,
#         "type": "audio_features",
#         "id": "7w5gqQzAZHkXmL1yADImpb",
#         "uri": "spotify:track:7w5gqQzAZHkXmL1yADImpb",
#         "track_href": "https://api.spotify.com/v1/tracks/7w5gqQzAZHkXmL1yADImpb",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/7w5gqQzAZHkXmL1yADImpb",
#         "duration_ms": 211133,
#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.254,
#         "energy": 0.814,
#         "key": 2,
#         "loudness": -5.058,
#         "mode": 1,
#         "speechiness": 0.0392,
#         "acousticness": 0.0148,
#         "instrumentalness": 0.00139,
#         "liveness": 0.156,
#         "valence": 0.556,
#         "tempo": 185.23,
#         "type": "audio_features",
#         "id": "7wsgeXJQTOTyZCn8F0SqFK",
#         "uri": "spotify:track:7wsgeXJQTOTyZCn8F0SqFK",
#         "track_href": "https://api.spotify.com/v1/tracks/7wsgeXJQTOTyZCn8F0SqFK",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/7wsgeXJQTOTyZCn8F0SqFK",
#         "duration_ms": 305667,
#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.441,
#         "energy": 0.512,
#         "key": 3,
#         "loudness": -10.785,
#         "mode": 1,
#         "speechiness": 0.0387,
#         "acousticness": 0.802,
#         "instrumentalness": 0.00264,
#         "liveness": 0.111,
#         "valence": 0.383,
#         "tempo": 87.815,
#         "type": "audio_features",
#         "id": "1R8uTKKZTWnHRkkpFWcJfd",
#         "uri": "spotify:track:1R8uTKKZTWnHRkkpFWcJfd",
#         "track_href": "https://api.spotify.com/v1/tracks/1R8uTKKZTWnHRkkpFWcJfd",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/1R8uTKKZTWnHRkkpFWcJfd",
#         "duration_ms": 350173,
#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.539,
#         "energy": 0.88,
#         "key": 0,
#         "loudness": -6.739,
#         "mode": 0,
#         "speechiness": 0.077,
#         "acousticness": 0.00247,
#         "instrumentalness": 8.48e-05,
#         "liveness": 0.238,
#         "valence": 0.531,
#         "tempo": 128.038,
#         "type": "audio_features",
#         "id": "3rydLuqW22lOXbzygKQuS5",
#         "uri": "spotify:track:3rydLuqW22lOXbzygKQuS5",
#         "track_href": "https://api.spotify.com/v1/tracks/3rydLuqW22lOXbzygKQuS5",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/3rydLuqW22lOXbzygKQuS5",
#         "duration_ms": 259560,
#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.443,
#         "energy": 0.338,
#         "key": 0,
#         "loudness": -12.287,
#         "mode": 1,
#         "speechiness": 0.0271,
#         "acousticness": 0.63,
#         "instrumentalness": 0,
#         "liveness": 0.129,
#         "valence": 0.198,
#         "tempo": 82.672,
#         "type": "audio_features",
#         "id": "32JdLIFho9kfeUzUhaWpMS",
#         "uri": "spotify:track:32JdLIFho9kfeUzUhaWpMS",
#         "track_href": "https://api.spotify.com/v1/tracks/32JdLIFho9kfeUzUhaWpMS",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/32JdLIFho9kfeUzUhaWpMS",
#         "duration_ms": 206200,
#         "time_signature": 3
#     }
# ]
# [
#     {
#         "danceability": 0.397,
#         "energy": 0.943,
#         "key": 11,
#         "loudness": -6.21,
#         "mode": 1,
#         "speechiness": 0.057,
#         "acousticness": 0.00378,
#         "instrumentalness": 3.25e-06,
#         "liveness": 0.62,
#         "valence": 0.411,
#         "tempo": 112.264,
#         "type": "audio_features",
#         "id": "5Ox3G1oWT9qu7YLK1HJNy0",
#         "uri": "spotify:track:5Ox3G1oWT9qu7YLK1HJNy0",
#         "track_href": "https://api.spotify.com/v1/tracks/5Ox3G1oWT9qu7YLK1HJNy0",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/5Ox3G1oWT9qu7YLK1HJNy0",
#         "duration_ms": 238987,
#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.436,
#         "energy": 0.918,
#         "key": 7,
#         "loudness": -4.633,
#         "mode": 1,
#         "speechiness": 0.0494,
#         "acousticness": 0.0983,
#         "instrumentalness": 0,
#         "liveness": 0.313,
#         "valence": 0.69,
#         "tempo": 137.913,
#         "type": "audio_features",
#         "id": "40M86ipe422BIg63Lcda0R",
#         "uri": "spotify:track:40M86ipe422BIg63Lcda0R",
#         "track_href": "https://api.spotify.com/v1/tracks/40M86ipe422BIg63Lcda0R",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/40M86ipe422BIg63Lcda0R",
#         "duration_ms": 241853,
#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.659,
#         "energy": 0.733,
#         "key": 2,
#         "loudness": -8.384,
#         "mode": 1,
#         "speechiness": 0.0506,
#         "acousticness": 0.0148,
#         "instrumentalness": 9.65e-06,
#         "liveness": 0.311,
#         "valence": 0.875,
#         "tempo": 110.257,
#         "type": "audio_features",
#         "id": "014Iv1iiaU5RGwqa2xiIct",
#         "uri": "spotify:track:014Iv1iiaU5RGwqa2xiIct",
#         "track_href": "https://api.spotify.com/v1/tracks/014Iv1iiaU5RGwqa2xiIct",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/014Iv1iiaU5RGwqa2xiIct",
#         "duration_ms": 136573,
#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.576,
#         "energy": 0.963,
#         "key": 0,
#         "loudness": -6.145,
#         "mode": 1,
#         "speechiness": 0.0548,
#         "acousticness": 0.0012,
#         "instrumentalness": 0.000762,
#         "liveness": 0.37,
#         "valence": 0.75,
#         "tempo": 111.738,
#         "type": "audio_features",
#         "id": "1QdbOe3o38SdDOxgMSfRGd",
#         "uri": "spotify:track:1QdbOe3o38SdDOxgMSfRGd",
#         "track_href": "https://api.spotify.com/v1/tracks/1QdbOe3o38SdDOxgMSfRGd",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/1QdbOe3o38SdDOxgMSfRGd",
#         "duration_ms": 239840,
#         "time_signature": 4
#     }
# ]
# [
#     {
#         "danceability": 0.361,
#         "energy": 0.88,
#         "key": 7,
#         "loudness": -6.281,
#         "mode": 1,
#         "speechiness": 0.0666,
#         "acousticness": 0.0252,
#         "instrumentalness": 0,
#         "liveness": 0.13,
#         "valence": 0.6,
#         "tempo": 143.849,
#         "type": "audio_features",
#         "id": "5CiuovveVr5FmINlJXkTxT",
#         "uri": "spotify:track:5CiuovveVr5FmINlJXkTxT",
#         "track_href": "https://api.spotify.com/v1/tracks/5CiuovveVr5FmINlJXkTxT",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/5CiuovveVr5FmINlJXkTxT",
#         "duration_ms": 194960,
#         "time_signature": 4
#     }
# ]

# %%
songs_info = {'Song ID' : song_id_2,'Danceability' : danceability, 'Energy' : energy, 'Key' : key, 'Loudness' : loudness,
              'Mode' : mode, 'Speechiness' : speechiness, 'Acousticness' : acousticness, 'Instrumentalness' : instrumentalness,
              'Liveness' : liveness, 'Valence' : valence, 'Tempo' : tempo, 'Duration ms' : duration_ms}

# %%
songs_info_df = pd.DataFrame(songs_info, columns = ['Song ID','Danceability', 'Energy', 'Key', 'Loudness',
              'Mode', 'Speechiness', 'Acousticness', 'Instrumentalness','Liveness', 'Valence', 'Tempo', 'Duration ms'])

# %%
songs_info_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 332 entries, 0 to 331
# Data columns (total 13 columns):
# Song ID             332 non-null object
# Danceability        332 non-null float64
# Energy              332 non-null float64
# Key                 332 non-null int64
# Loudness            332 non-null float64
# Mode                332 non-null int64
# Speechiness         332 non-null float64
# Acousticness        332 non-null float64
# Instrumentalness    332 non-null float64
# Liveness            332 non-null float64
# Valence             332 non-null float64
# Tempo               332 non-null float64
# Duration ms         332 non-null int64
# dtypes: float64(9), int64(3), object(1)
# memory usage: 33.8+ KB

# %%
songs_info_df = pd.merge(songs_info_df,playlists_info_df[['Song ID','Song Popularity']],on='Song ID', how='left')

# %%
songs_info_df.head()
# Out:
#                   Song ID  Danceability  Energy  Key  Loudness  Mode  \
# 0  1R8uTKKZTWnHRkkpFWcJfd         0.441   0.512    3   -10.785     1
# 1  1R8uTKKZTWnHRkkpFWcJfd         0.441   0.512    3   -10.785     1
# 2  6162MRbYpLu1ZJHe7zHh8H         0.620   0.902    7    -4.967     1
# 3  4sFhx3eU00RrmrOsJxEnAs         0.216   0.829   11    -3.583     0
# 4  3H7sv3Krffn15BufUuXzf3         0.386   0.607   10    -7.700     1
#
#    Speechiness  Acousticness  Instrumentalness  Liveness  Valence    Tempo  \
# 0       0.0387       0.80200          0.002640    0.1110    0.383   87.815
# 1       0.0387       0.80200          0.002640    0.1110    0.383   87.815
# 2       0.0270       0.02930          0.000000    0.1120    0.775  104.255
# 3       0.0443       0.00174          0.527000    0.0772    0.665  179.758
# 4       0.0261       0.01120          0.000014    0.0880    0.532  147.207
#
#    Duration ms  Song Popularity
# 0       350173               42
# 1       350173               42
# 2       217787               48
# 3       207760                1
# 4       425653               69

# %%
#Custome color palette
red_blue = ['#19B5FE', '#EF4836']
palette = sns.color_palette(red_blue)
sns.set_palette(palette)
sns.set_style("white")

# %%
pos_tempo = songs_info_df[songs_info_df['Song Popularity'] > 50]['Tempo']
neg_tempo = songs_info_df[songs_info_df['Song Popularity'] < 50]['Tempo']
pos_dance = songs_info_df[songs_info_df['Song Popularity'] > 50]['Danceability']
neg_dance = songs_info_df[songs_info_df['Song Popularity'] < 50]['Danceability']
pos_duration = songs_info_df[songs_info_df['Song Popularity'] > 50]['Duration ms']
neg_duration = songs_info_df[songs_info_df['Song Popularity'] < 50]['Duration ms']
pos_loudness = songs_info_df[songs_info_df['Song Popularity'] > 50]['Loudness']
neg_loudness = songs_info_df[songs_info_df['Song Popularity'] < 50]['Loudness']
pos_speechiness = songs_info_df[songs_info_df['Song Popularity'] > 50]['Speechiness']
neg_speechiness = songs_info_df[songs_info_df['Song Popularity'] < 50]['Speechiness']
pos_valence = songs_info_df[songs_info_df['Song Popularity'] > 50]['Valence']
neg_valence = songs_info_df[songs_info_df['Song Popularity'] < 50]['Valence']
pos_energy = songs_info_df[songs_info_df['Song Popularity'] > 50]['Energy']
neg_energy = songs_info_df[songs_info_df['Song Popularity'] < 50]['Energy']
pos_acousticness = songs_info_df[songs_info_df['Song Popularity'] > 50]['Acousticness']
neg_acousticness = songs_info_df[songs_info_df['Song Popularity'] < 50]['Acousticness']
pos_key = songs_info_df[songs_info_df['Song Popularity'] > 50]['Key']
neg_key = songs_info_df[songs_info_df['Song Popularity'] < 50]['Key']
pos_instrumentalness = songs_info_df[songs_info_df['Song Popularity'] > 50]['Instrumentalness']
neg_instrumentalness = songs_info_df[songs_info_df['Song Popularity'] < 50]['Instrumentalness']

# %%
fig = plt.figure(figsize=(12,8))
plt.title("Song tempo high/low popularity distribution")
pos_tempo.hist(alpha=0.7, bins = 30, label='high popularity')
neg_tempo.hist(alpha=0.7, bins = 30, label='low popularity')
plt.legend(loc = 'upper right')

# %%
fig2 = plt.figure(figsize=(15,15))

# Danceability
ax3 = fig2.add_subplot(331)
ax3.set_xlabel('Danceability')
ax3.set_ylabel('Count')
ax3.set_title('Song Danceability Popularity Distribution')
pos_dance.hist(alpha=0.5, bins=30)
ax4 = fig2.add_subplot(331)
neg_dance.hist(alpha=0.5, bins=30)

# Duration
ax5 = fig2.add_subplot(332)
ax5.set_xlabel('Duration MS')
ax5.set_ylabel('Count')
ax5.set_title('Song Duration Populatiry Distribution')
pos_duration.hist(alpha=0.5, bins=30)
ax6 = fig2.add_subplot(332)
neg_duration.hist(alpha=0.5, bins=30)

# Loudness
ax7 = fig2.add_subplot(333)
ax7.set_xlabel('Loudness')
ax7.set_ylabel('Count')
ax7.set_title('Song Loudness Popularity Distribution')
pos_loudness.hist(alpha=0.5, bins=30)
ax8 = fig2.add_subplot(333)
neg_loudness.hist(alpha=0.5, bins=30)

# Speechiness
ax9 = fig2.add_subplot(334)
ax9.set_xlabel('Speechiness')
ax9.set_ylabel('Count')
ax9.set_title('Song Speechiness Popularity Distribution')
pos_speechiness.hist(alpha=0.5, bins=30)
ax10 = fig2.add_subplot(334)
neg_speechiness.hist(alpha=0.5, bins=30)

# Valence
ax11 = fig2.add_subplot(335)
ax11.set_xlabel('Valence')
ax11.set_ylabel('Count')
ax11.set_title('Song Valence Popularity Distribution')
pos_valence.hist(alpha=0.5, bins=30)
ax12 = fig2.add_subplot(335)
neg_valence.hist(alpha=0.5, bins=30)

# Energy
ax13 = fig2.add_subplot(335)
ax13.set_xlabel('Energy')
ax13.set_ylabel('Count')
ax13.set_title('Song Energy Popularity Distribution')
pos_energy.hist(alpha=0.5, bins=30)
ax14 = fig2.add_subplot(335)
neg_energy.hist(alpha=0.5, bins=30)

# Acousticness
ax15 = fig2.add_subplot(336)
ax15.set_xlabel('Acousticness')
ax15.set_ylabel('Count')
ax15.set_title('Song Acousticness Popularity Distribution')
pos_acousticness.hist(alpha=0.5, bins=30)
ax16 = fig2.add_subplot(336)
neg_acousticness.hist(alpha=0.5, bins=30)

# Key
ax17 = fig2.add_subplot(337)
ax17.set_xlabel('Key')
ax17.set_ylabel('Count')
ax17.set_title('Song Key Popularity Distribution')
pos_key.hist(alpha=0.5, bins=30)
ax18 = fig2.add_subplot(337)
neg_key.hist(alpha=0.5, bins=30)

# Instrumentalness
ax19 = fig2.add_subplot(338)
ax19.set_xlabel('Instrumentalness')
ax19.set_ylabel('Count')
ax19.set_title('Song Instrumentalness Popularity Distribution')
pos_instrumentalness.hist(alpha=0.5, bins=30)
ax20 = fig2.add_subplot(338)
neg_instrumentalness.hist(alpha=0.5, bins=30)
# Out:
# C:\Users\Giorgia\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# # Using K-Means to create some clusters

# %%
from sklearn.cluster import KMeans

import hypertools as hyp

km = KMeans(n_clusters=4, init='k-means++', n_init=10)

# %%
songs_info_clusters = songs_info_df.drop(['Song ID', 'Song Popularity', 'Key', 'Mode', 'Valence', 'Tempo', 'Duration ms'], axis = 1)
songs_info_clusters.head()
# Out:
#    Danceability  Energy  Loudness  Speechiness  Acousticness  \
# 0         0.441   0.512   -10.785       0.0387       0.80200
# 1         0.441   0.512   -10.785       0.0387       0.80200
# 2         0.620   0.902    -4.967       0.0270       0.02930
# 3         0.216   0.829    -3.583       0.0443       0.00174
# 4         0.386   0.607    -7.700       0.0261       0.01120
#
#    Instrumentalness  Liveness
# 0          0.002640    0.1110
# 1          0.002640    0.1110
# 2          0.000000    0.1120
# 3          0.527000    0.0772
# 4          0.000014    0.0880

# %%
km.fit(songs_info_clusters)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=4, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
x = km.fit_predict(songs_info_clusters)
x
# Out:
# array([2, 2, 1, 1, 3, 3, 3, 3, 0, 0, 1, 0, 0, 3, 3, 3, 3, 1, 1, 3, 2, 0, 3,
#        3, 1, 3, 0, 1, 3, 1, 1, 3, 2, 3, 3, 1, 1, 2, 3, 3, 0, 3, 0, 3, 1, 1,
#        3, 2, 2, 3, 0, 3, 0, 3, 0, 1, 1, 0, 3, 3, 3, 0, 1, 0, 2, 3, 1, 1, 2,
#        1, 0, 3, 3, 3, 0, 3, 3, 1, 3, 1, 0, 0, 2, 1, 3, 3, 2, 0, 3, 2, 0, 3,
#        3, 3, 3, 3, 3, 2, 0, 1, 3, 1, 2, 1, 0, 3, 1, 0, 0, 2, 3, 3, 1, 1, 2,
#        0, 3, 3, 1, 1, 0, 3, 2, 1, 3, 1, 1, 0, 3, 0, 2, 3, 1, 1, 0, 3, 1, 3,
#        3, 0, 0, 0, 3, 1, 1, 0, 0, 3, 0, 1, 3, 3, 3, 1, 0, 0, 0, 0, 3, 2, 1,
#        1, 1, 1, 1, 3, 3, 3, 1, 3, 0, 2, 1, 1, 3, 1, 3, 2, 2, 1, 3, 3, 3, 3,
#        2, 2, 3, 0, 3, 2, 3, 0, 3, 3, 1, 2, 2, 1, 0, 2, 3, 0, 3, 0, 3, 0, 1,
#        3, 3, 0, 3, 0, 3, 2, 0, 0, 2, 0, 2, 3, 2, 0, 1, 3, 3, 3, 0, 1, 0, 0,
#        0, 0, 3, 1, 0, 3, 3, 3, 0, 2, 2, 2, 3, 3, 0, 3, 1, 2, 3, 3, 3, 3, 1,
#        2, 0, 0, 3, 3, 0, 1, 0, 3, 0, 3, 0, 3, 2, 0, 0, 3, 0, 3, 3, 1, 3, 3,
#        3, 3, 0, 1, 1, 3, 0, 0, 3, 1, 3, 2, 3, 2, 1, 3, 1, 3, 0, 3, 3, 0, 3,
#        0, 0, 0, 3, 0, 1, 3, 3, 1, 3, 3, 0, 1, 1, 1, 2, 1, 1, 1, 3, 0, 1, 1,
#        1, 0, 0, 3, 1, 2, 2, 3, 2, 3, 1, 0, 3, 3])

# %%
songs_info_clusters["Cluster"]= x
songs_info_clusters.head()
# Out:
#    Danceability  Energy  Loudness  Speechiness  Acousticness  \
# 0         0.441   0.512   -10.785       0.0387       0.80200
# 1         0.441   0.512   -10.785       0.0387       0.80200
# 2         0.620   0.902    -4.967       0.0270       0.02930
# 3         0.216   0.829    -3.583       0.0443       0.00174
# 4         0.386   0.607    -7.700       0.0261       0.01120
#
#    Instrumentalness  Liveness  Cluster
# 0          0.002640    0.1110        2
# 1          0.002640    0.1110        2
# 2          0.000000    0.1120        1
# 3          0.527000    0.0772        1
# 4          0.000014    0.0880        3

# %%
target = songs_info_clusters['Cluster']
songs_info_clusters = songs_info_clusters.drop('Cluster', axis=1)
group = target.astype('str')

# %%
songs_info_df["Cluster"]= x
songs_info_df.head()
# Out:
#                   Song ID  Danceability  Energy  Key  Loudness  Mode  \
# 0  1R8uTKKZTWnHRkkpFWcJfd         0.441   0.512    3   -10.785     1
# 1  1R8uTKKZTWnHRkkpFWcJfd         0.441   0.512    3   -10.785     1
# 2  6162MRbYpLu1ZJHe7zHh8H         0.620   0.902    7    -4.967     1
# 3  4sFhx3eU00RrmrOsJxEnAs         0.216   0.829   11    -3.583     0
# 4  3H7sv3Krffn15BufUuXzf3         0.386   0.607   10    -7.700     1
#
#    Speechiness  Acousticness  Instrumentalness  Liveness  Valence    Tempo  \
# 0       0.0387       0.80200          0.002640    0.1110    0.383   87.815
# 1       0.0387       0.80200          0.002640    0.1110    0.383   87.815
# 2       0.0270       0.02930          0.000000    0.1120    0.775  104.255
# 3       0.0443       0.00174          0.527000    0.0772    0.665  179.758
# 4       0.0261       0.01120          0.000014    0.0880    0.532  147.207
#
#    Duration ms  Song Popularity  Cluster
# 0       350173               42        2
# 1       350173               42        2
# 2       217787               48        1
# 3       207760                1        1
# 4       425653               69        3

# %%
songs_info_df_sorted_cluster = songs_info_df.sort_values(['Cluster'])
songs_info_df_sorted_cluster = songs_info_df_sorted_cluster.reset_index(drop=True)
songs_info_df_sorted_cluster
# Out:
#                     Song ID  Danceability  Energy  Key  Loudness  Mode  \
# 0    5N8JUiG7xDh6Qj2bhySXaC         0.689   0.602    8    -9.053     1
# 8         248880               17        0
# 9         258093                9        0
# 10        280667               15        0
# 11        279960                6        0
# 12        188867               32        0
# 13        164293                2        0
# 14        300640               15        0
# 15        199020               65        0
# 16        183197               48        0
# 17        200857                6        0
# 18        175857                4        0
# 19        285173                0        0
# 20        253079               49        0
# 21        244867               60        0
# 22        367373               14        0
# 23        177406               53        0
# 24        418000               28        0
# 25        199904               11        0
# 26        299839               56        0
# 27        268333               68        0
# 28        385879               12        0
# 29        248000               42        0
# ..           ...              ...      ...
# 306       441427               17        3
# 307       244173               35        3
# 308       485933               13        3
# 309       244693               50        3
# 310       260067               50        3
# 311       560760               26        3
# 312       242533               41        3
# 313       353400               43        3
# 314       367027               33        3
# 315       248200               31        3
# 316       257173                1        3
# 317       173333               15        3
# 318       206099               22        3
# 319       180859               17        3
# 320       177040                8        3
# 321       216907                0        3
# 322       252140               50        3
# 323       333514               42        3
# 324       214973               34        3
# 325       206200               21        3
# 326       293427               50        3
# 327       288053                2        3
# 328       413880               17        3
# 329       178440               72        3
# 330       192427               54        3
# 331       239840               45        3
# 332       179507               19        3
# 333       236213               42        3
# 334       147502               51        3
# 335       194960               35        3
#
# [336 rows x 15 columns]

# %%
plt.scatter(songs_info_df_sorted_cluster['Cluster'], songs_info_df_sorted_cluster['Danceability'],
            c=x, s=50, cmap='viridis')
plt.show()

# %%
plt.scatter(songs_info_df_sorted_cluster['Cluster'], songs_info_df_sorted_cluster['Energy'],
            c=x, s=50, cmap='viridis')
plt.show()

# %%
plt.scatter(songs_info_df_sorted_cluster['Cluster'], songs_info_df_sorted_cluster['Loudness'],
            c=x, s=50, cmap='viridis')
plt.show()

# %%
plt.scatter(songs_info_df_sorted_cluster['Cluster'], songs_info_df_sorted_cluster['Speechiness'],
            c=x, s=50, cmap='viridis')
plt.show()

# %%
plt.scatter(songs_info_df_sorted_cluster['Cluster'], songs_info_df_sorted_cluster['Acousticness'],
            c=x, s=50, cmap='viridis')
plt.show()

# %%
plt.scatter(songs_info_df_sorted_cluster['Cluster'], songs_info_df_sorted_cluster['Instrumentalness'],
            c=x, s=50, cmap='viridis')
plt.show()

# %%
plt.scatter(songs_info_df_sorted_cluster['Cluster'], songs_info_df_sorted_cluster['Liveness'],
            c=x, s=50, cmap='viridis')
plt.show()

# %%
hyp.plot(songs_info_clusters, '.', group=group, model='TSNE', ndims=2, legend=[1,2,3,4], 
         title = "2D Representation of the Main Cluster using t-SNE")
# Out:
# C:\Users\Giorgia\Anaconda3\lib\site-packages\hypertools\plot\plot.py:227: UserWarning: Model and model_params arguments will be deprecated. Please use                       reduce keyword argument. See docs for details: http://hypertools.readthedocs.io/en/latest/hypertools.plot.html#hypertools.plot
#   reduce keyword argument. See docs for details: http://hypertools.readthedocs.io/en/latest/hypertools.plot.html#hypertools.plot')
# C:\Users\Giorgia\Anaconda3\lib\site-packages\hypertools\plot\plot.py:233: UserWarning: Group will be deprecated. Please use hue keyword argument. See docs for details: http://hypertools.readthedocs.io/en/latest/hypertools.plot.html#hypertools.plot
#   warnings.warn('Group will be deprecated. Please use '

# %%
hyp.plot(songs_info_clusters, '.', group=group, model='PCA', ndims=2, legend=[1,2,3,4], 
         title = "2D Representation of the Main Cluster using PCA")
# Out:
# C:\Users\Giorgia\Anaconda3\lib\site-packages\hypertools\plot\plot.py:227: UserWarning: Model and model_params arguments will be deprecated. Please use                       reduce keyword argument. See docs for details: http://hypertools.readthedocs.io/en/latest/hypertools.plot.html#hypertools.plot
#   reduce keyword argument. See docs for details: http://hypertools.readthedocs.io/en/latest/hypertools.plot.html#hypertools.plot')
# C:\Users\Giorgia\Anaconda3\lib\site-packages\hypertools\plot\plot.py:233: UserWarning: Group will be deprecated. Please use hue keyword argument. See docs for details: http://hypertools.readthedocs.io/en/latest/hypertools.plot.html#hypertools.plot
#   warnings.warn('Group will be deprecated. Please use '

# %%
hyp.plot(songs_info_clusters, '.', group=group, model='TSNE', ndims=3, legend=[1,2,3,4], 
         title = "3D Representation of the Main Cluster using t-SNE")
# Out:
# C:\Users\Giorgia\Anaconda3\lib\site-packages\hypertools\plot\plot.py:227: UserWarning: Model and model_params arguments will be deprecated. Please use                       reduce keyword argument. See docs for details: http://hypertools.readthedocs.io/en/latest/hypertools.plot.html#hypertools.plot
#   reduce keyword argument. See docs for details: http://hypertools.readthedocs.io/en/latest/hypertools.plot.html#hypertools.plot')
# C:\Users\Giorgia\Anaconda3\lib\site-packages\hypertools\plot\plot.py:233: UserWarning: Group will be deprecated. Please use hue keyword argument. See docs for details: http://hypertools.readthedocs.io/en/latest/hypertools.plot.html#hypertools.plot
#   warnings.warn('Group will be deprecated. Please use '
